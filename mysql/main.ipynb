# %%
from mysql_upload import upload_csv_folder, upload_csv, upload_excel, upload_txt_folder, upload_txt
from mysql_query import query_data_to_dataframe, clear_or_drop_table, execute_custom_query, insert_data_from_dataframe, drop_database
import duckdb
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from mysql_upload import upload_csv_folder, upload_csv, upload_excel, upload_txt_folder, upload_txt
#       2 from mysql_query import query_data_to_dataframe, clear_or_drop_table, execute_custom_query, insert_data_from_dataframe, drop_database
#       3 import duckdb
#       4 import pandas as pd
#
# ImportError: cannot import name 'upload_txt_folder' from 'mysql_upload' (c:\Users\Thu Huyen\OneDrive\Desktop\In Progress\Git-Test\mysql\mysql_upload.py)

# %%
db_name = "testing"
# files_list = ['World Flags Dataset Addition.xlsx']
# subfolder = "fin_data"
MODE ="local"

# %%
upload_csv_folder("traffic_cus_uk", db_name="testing_auto", mode=MODE)
# upload_excel(db_name=db_name, mode=MODE)
# upload_csv(subfolder="Traffic", db_name=db_name, mode=MODE)
# Out:
# 📂 Path: c:\Users\Thu Huyen\OneDrive\Desktop\In Progress\Git-Test\data\traffic_cus_uk
# 🗄️  Target DB: testing_auto
# 📄 Merging 12 file(s) → table 'traffic_cus_uk'...
#
#   📘 Loaded Excel '2020_01.xlsx' (Sheet: Sheet1) — 1654 rows
#   📘 Loaded Excel '2020_02.xlsx' (Sheet: Sheet1) — 1453 rows
#   📘 Loaded Excel '2020_03.xlsx' (Sheet: Sheet1) — 1792 rows
#   📘 Loaded Excel '2020_04.xlsx' (Sheet: Sheet1) — 1705 rows
#   📘 Loaded Excel '2020_05.xlsx' (Sheet: Sheet1) — 1640 rows
#   📘 Loaded Excel '2020_06.xlsx' (Sheet: Sheet1) — 1676 rows
#   📘 Loaded Excel '2020_07.xlsx' (Sheet: Sheet1) — 1657 rows
#   📘 Loaded Excel '2020_08.xlsx' (Sheet: Sheet1) — 1509 rows
#   📘 Loaded Excel '2020_09.xlsx' (Sheet: Sheet1) — 1561 rows
#   📘 Loaded Excel '2020_10.xlsx' (Sheet: Sheet1) — 1486 rows
#   📘 Loaded Excel '2020_11.xlsx' (Sheet: Sheet1) — 1290 rows
#   📘 Loaded Excel '2020_12.xlsx' (Sheet: Sheet1) — 466 rows
#
#   🔗 Total merged: 17889 rows từ tất cả các file/sheets (chỉ chứa nội dung gốc).
#   ✅ Table 'traffic_cus_uk' — 17889 rows uploaded.

# %%
TARGET_DB = "finance_db"
TABLE = "fin_data"

# data_test = {
#     "Project Name": ["Dự án A", "Dự án B"],
#     "Funding": [50000, 75000],
#     "Status": ["Active", "Pending"]
# }
# df_new = pd.DataFrame(data_test)

# print("\n1. Insert dữ liệu từ DataFrame vào MySQL:")
# insert_data_from_dataframe(df_new, table_name=TABLE, db_name=TARGET_DB, if_exists="append")


# print("\n2. Truy vấn dữ liệu:")
# select_sql = f"SELECT * FROM `{TABLE}` WHERE funding > 60000;"
# df_result = query_data_to_dataframe(select_sql, db_name=TARGET_DB)
# print(df_result)

# print("\n3. Cập nhật dữ liệu (UPDATE):")
# update_sql = f"UPDATE `{TABLE}` SET status = :new_status WHERE project_name = :p_name;"
# execute_custom_query(update_sql, params={"new_status": "Completed", "p_name": "Dự án B"}, db_name=TARGET_DB)

# print("\nKiểm tra lại dữ liệu sau khi UPDATE:")
# print(query_data_to_dataframe(f"SELECT * FROM `{TABLE}`;", db_name=TARGET_DB))


print("\n4. Xóa bảng:")
clear_or_drop_table(table_name=TABLE, db_name=TARGET_DB, action="drop")

print("\n Drop db:")
drop_database(db_name=TARGET_DB, mode=MODE)
# Out:
# 4. Xóa bảng:
# 🗑️  Đã xóa hoàn toàn bảng 'fin_data' khỏi DB 'finance_db'.
